# %% [markdown]
# # <center>Web Scraping by API </center>

# %% [markdown]
# ## 1. Scrape data through APIs
# - Online content providers usually provide APIs for you to access data. Two types of APIs:
#    * Python packages: e.g. tweepy package from Twitter
#    * REST APIs: e.g. OMDB APIs (http://www.omdbapi.com), or TMDB (https://developers.themoviedb.org/3/getting-started)
# - You need to read documentation of APIs to figure out how to access data

# %% [markdown]
# ## 2. Scrape data by REST APIs (e.g. OMDB API)
# - A REST API is a web service that uses `HTTP` requests to `GET`, `PUT`, `POST` and `DELETE` data
# - Example:
#     - https://groceries.asda.com/api/items/search<font color="blue"><b>?</b></font><font color='green'><b>keyword</b></font>=<font color='red'><b>yogurt<b></font><front color='purple'><b>&</b></font><font color='green'><b>r</b></font>=<font color='red'><b>json<b></font>, where
#         - `?`: separate API endpoint  `https://groceries.asda.com/api/items/search` from parameters
#         - `keyword=yogurt`: search `yogurt` on parameter `keyword`
#         - `&`: combine multiple search criteria
#         - `r=json`: result is in json format
#     - You can directly paste the above API to your browser
#     - Or issue API calls using requests
# - You need to read API documentation to understand how to specify parameters

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import requests
import json
import pandas as pd

# %%
import requests
import json

keyword = 'yogurt'


url="https://groceries.asda.com/api/items/search?keyword=" + keyword + "&r=json"

print(url)

# invoke the API 
r = requests.get(url)

# if the API call returns a successful response
if r.status_code==200:
    
    # This API call returns a json object
    # r.json() gives the json object
    # json. dumps() function converts a Python object into a json string
    result = r.json()
    print (json.dumps(result, indent=4))
# Out:
# https://groceries.asda.com/api/items/search?keyword=yogurt&r=json
# {
#     "statusMessage": "The API Item Search was executed successfully",
#     "errors": [],
#     "keyword": "yogurt",
#     "storeId": "4565",
#     "autoCorrectedTerm": "",
#     "didYouMeanTerm": "",
#     "isHookLogicInsert": "false",
#     "totalResult": "413",
#     "currentPage": "1",
#     "resultsStartIndex": "1",
#     "resultsEndIndex": "60",
#     "maxPages": "7",
#     "qusApplied": false,
#     "productBoostingDetails": "0^rule_5f8046bf0931946b86fb4387^^^Default",
#     "monetizedItems": [],
#     "items": [
#         {
#             "shelfId": "1215286383583",
#             "shelfName": "Corners",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a33.5::true",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6362225",
#             "promoDetailFull": "10 for \u00a33.5",
#             "availability": "A",
#             "totalReviewCount": "8",
#             "asdaSuggest": "",
#             "itemName": "Vanilla Yogurt with Chocolate\u00a0Balls",
#             "price": "\u00a30.55",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000120228362",
#             "promoId": "ls91195",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Corner",
#             "promoType": "No Promo",
#             "weight": "130g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a33.50",
#             "productAttribute": "",
#             "scene7AssetId": "4025500245221",
#             "promoDetail": "10 for \u00a33.5",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.625",
#             "name": "Muller Corner Vanilla Yogurt with Chocolate\u00a0Balls",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000120228362",
#             "pricePerUOM": "",
#             "searchTuningScore": "1.869282E7",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286383583",
#             "shelfName": "Corners",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a33.5::true",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6362239",
#             "promoDetailFull": "10 for \u00a33.5",
#             "availability": "A",
#             "totalReviewCount": "3",
#             "asdaSuggest": "",
#             "itemName": "Strawberry Yogurt",
#             "price": "\u00a30.55",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000120228322",
#             "promoId": "ls91195",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Corner",
#             "promoType": "No Promo",
#             "weight": "143g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a33.50",
#             "productAttribute": "",
#             "scene7AssetId": "4025500245092",
#             "promoDetail": "10 for \u00a33.5",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "3.6667",
#             "name": "Muller Corner Strawberry Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000120228322",
#             "pricePerUOM": "",
#             "searchTuningScore": "1.3473809E7",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286383583",
#             "shelfName": "Corners",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a33.5::true",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6362227",
#             "promoDetailFull": "10 for \u00a33.5",
#             "availability": "A",
#             "totalReviewCount": "9",
#             "asdaSuggest": "",
#             "itemName": "Banana Yogurt with Chocolate Flakes",
#             "price": "\u00a30.55",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000120228335",
#             "promoId": "ls91195",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Corner",
#             "promoType": "No Promo",
#             "weight": "130g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a33.50",
#             "productAttribute": "",
#             "scene7AssetId": "4025500245207",
#             "promoDetail": "10 for \u00a33.5",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "3.6667",
#             "name": "Muller Corner Banana Yogurt with Chocolate Flakes",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000120228335",
#             "pricePerUOM": "",
#             "searchTuningScore": "1.2041251E7",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286383583",
#             "shelfName": "Corners",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a33.5::true",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6362229",
#             "promoDetailFull": "10 for \u00a33.5",
#             "availability": "A",
#             "totalReviewCount": "8",
#             "asdaSuggest": "",
#             "itemName": "Toffee Yogurt with Chocolate Hoops",
#             "price": "\u00a30.55",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000120228313",
#             "promoId": "ls91195",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Corner",
#             "promoType": "No Promo",
#             "weight": "130g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a33.50",
#             "productAttribute": "",
#             "scene7AssetId": "4025500245146",
#             "promoDetail": "10 for \u00a33.5",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "3.75",
#             "name": "Muller Corner Toffee Yogurt with Chocolate Hoops",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000120228313",
#             "pricePerUOM": "",
#             "searchTuningScore": "8325497.0",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286383583",
#             "shelfName": "Corners",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a33.5::true",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6362233",
#             "promoDetailFull": "10 for \u00a33.5",
#             "availability": "A",
#             "totalReviewCount": "10",
#             "asdaSuggest": "",
#             "itemName": "Strawberry Yogurt with White Chocolate Shortcake Balls",
#             "price": "\u00a30.55",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000120228351",
#             "promoId": "ls91195",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Corner",
#             "promoType": "No Promo",
#             "weight": "130g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a33.50",
#             "productAttribute": "",
#             "scene7AssetId": "4025500245160",
#             "promoDetail": "10 for \u00a33.5",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "3.8",
#             "name": "Muller Corner Strawberry Yogurt with White Chocolate Shortcake Balls",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000120228351",
#             "pricePerUOM": "",
#             "searchTuningScore": "7703160.0",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000977060",
#             "shelfName": "Fat Free & Low Fat",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a33.5::true",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6346362",
#             "promoDetailFull": "10 for \u00a33.5",
#             "availability": "A",
#             "totalReviewCount": "8",
#             "asdaSuggest": "",
#             "itemName": "Fat Free Toffee Yogurt",
#             "price": "\u00a30.55",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000116808315",
#             "promoId": "ls91195",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Light",
#             "promoType": "No Promo",
#             "weight": "160g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a33.50",
#             "productAttribute": "",
#             "scene7AssetId": "4025500243579",
#             "promoDetail": "10 for \u00a33.5",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.5",
#             "name": "Muller Light Fat Free Toffee Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000116808315",
#             "pricePerUOM": "",
#             "searchTuningScore": "7371434.5",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286423096",
#             "shelfName": "Activia Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "4::for::\u00a33::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6202233",
#             "promoDetailFull": "4 for \u00a33",
#             "availability": "A",
#             "totalReviewCount": "38",
#             "asdaSuggest": "",
#             "itemName": "Low Fat Vanilla Yogurt & Granola",
#             "price": "\u00a30.90",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000078311452",
#             "promoId": "ls90172",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Activia",
#             "promoType": "No Promo",
#             "weight": "165g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "4",
#             "promoValue": "\u00a33",
#             "productAttribute": "",
#             "scene7AssetId": "5060360502960",
#             "promoDetail": "4 for \u00a33",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.4211",
#             "name": "Activia Low Fat Vanilla Yogurt & Granola",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000078311452",
#             "pricePerUOM": "",
#             "searchTuningScore": "6340794.5",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000977060",
#             "shelfName": "Fat Free & Low Fat",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a33.5::true",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6346360",
#             "promoDetailFull": "10 for \u00a33.5",
#             "availability": "A",
#             "totalReviewCount": "10",
#             "asdaSuggest": "",
#             "itemName": "Fat Free Banana and Custard Yogurt",
#             "price": "\u00a30.55",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000116808339",
#             "promoId": "ls91195",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Light",
#             "promoType": "No Promo",
#             "weight": "160g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a33.50",
#             "productAttribute": "",
#             "scene7AssetId": "4025500243555",
#             "promoDetail": "10 for \u00a33.5",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.1",
#             "name": "Muller Light Fat Free Banana and Custard Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000116808339",
#             "pricePerUOM": "",
#             "searchTuningScore": "5353415.5",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000977060",
#             "shelfName": "Fat Free & Low Fat",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a33.5::true",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6346354",
#             "promoDetailFull": "10 for \u00a33.5",
#             "availability": "A",
#             "totalReviewCount": "7",
#             "asdaSuggest": "",
#             "itemName": "Fat Free Strawberry Yogurt",
#             "price": "\u00a30.55",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000116808369",
#             "promoId": "ls91195",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Light",
#             "promoType": "No Promo",
#             "weight": "160g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a33.50",
#             "productAttribute": "",
#             "scene7AssetId": "4025500243357",
#             "promoDetail": "10 for \u00a33.5",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.2857",
#             "name": "Muller Light Fat Free Strawberry Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000116808369",
#             "pricePerUOM": "",
#             "searchTuningScore": "5169195.5",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286423096",
#             "shelfName": "Activia Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "4582588",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "50",
#             "asdaSuggest": "",
#             "itemName": "Intensely Creamy Strawberry Yogurts",
#             "price": "\u00a31.25",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910001285499",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a32.00",
#             "brandName": "Activia",
#             "promoType": "Rollback",
#             "weight": "4x110g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5060360500003",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.46",
#             "name": "Activia Intensely Creamy Strawberry Yogurts",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910001285499",
#             "pricePerUOM": "",
#             "searchTuningScore": "5081264.5",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286423096",
#             "shelfName": "Activia Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "4582592",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "12",
#             "asdaSuggest": "",
#             "itemName": "Intensely Creamy Cherry Yogurts",
#             "price": "\u00a31.25",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910001285443",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a32.00",
#             "brandName": "Activia",
#             "promoType": "Rollback",
#             "weight": "4x110g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5060360500027",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.75",
#             "name": "Activia Intensely Creamy Cherry Yogurts",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910001285443",
#             "pricePerUOM": "",
#             "searchTuningScore": "3844005.0",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000977060",
#             "shelfName": "Fat Free & Low Fat",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a33.5::true",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6346366",
#             "promoDetailFull": "10 for \u00a33.5",
#             "availability": "A",
#             "totalReviewCount": "9",
#             "asdaSuggest": "",
#             "itemName": "Fat Free Vanilla & Dark Chocolate Yogurt",
#             "price": "\u00a30.55",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000116808389",
#             "promoId": "ls91195",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Light",
#             "promoType": "No Promo",
#             "weight": "160g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a33.50",
#             "productAttribute": "",
#             "scene7AssetId": "4025500243616",
#             "promoDetail": "10 for \u00a33.5",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.5556",
#             "name": "Muller Light Fat Free Vanilla & Dark Chocolate Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000116808389",
#             "pricePerUOM": "",
#             "searchTuningScore": "3490875.5",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000976118",
#             "shelfName": "Big Pots",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "3689730",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "56",
#             "asdaSuggest": "",
#             "itemName": "Mango, Papaya & Passion Fruit Yogurt",
#             "price": "\u00a31.00",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910000470832",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a31.25",
#             "brandName": "Onken",
#             "promoType": "Rollback",
#             "weight": "450g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "7610900037360",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.7857",
#             "name": "Onken Mango, Papaya & Passion Fruit Yogurt",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910000470832",
#             "pricePerUOM": "",
#             "searchTuningScore": "3108602.8",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286423096",
#             "shelfName": "Activia Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "4582596",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "50",
#             "asdaSuggest": "",
#             "itemName": "Intensely Creamy Peach Yogurts",
#             "price": "\u00a31.25",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910001285082",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a32.00",
#             "brandName": "Activia",
#             "promoType": "Rollback",
#             "weight": "4x110g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5060360500041",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.76",
#             "name": "Activia Intensely Creamy Peach Yogurts",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910001285082",
#             "pricePerUOM": "",
#             "searchTuningScore": "2918421.5",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000976085",
#             "shelfName": "Kids Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "4786440",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "51",
#             "asdaSuggest": "",
#             "itemName": "Apricot, Strawberry & Raspberry Yogurt",
#             "price": "\u00a32.00",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910001458433",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a33.00",
#             "brandName": "Petits Filous",
#             "promoType": "Rollback",
#             "weight": "18x47g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "3329770051621",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.4706",
#             "name": "Petits Filous Apricot, Strawberry & Raspberry Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600050"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910001458433",
#             "pricePerUOM": "",
#             "searchTuningScore": "2788633.8",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000976118",
#             "shelfName": "Big Pots",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "3689722",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "37",
#             "asdaSuggest": "",
#             "itemName": "Fat Free Strawberry Yogurt",
#             "price": "\u00a31.00",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910000470905",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a31.25",
#             "brandName": "Onken",
#             "promoType": "Rollback",
#             "weight": "450g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "7610900037421",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.8108",
#             "name": "Onken Fat Free Strawberry Yogurt",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910000470905",
#             "pricePerUOM": "",
#             "searchTuningScore": "2450505.2",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000976118",
#             "shelfName": "Big Pots",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "3689724",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "35",
#             "asdaSuggest": "",
#             "itemName": "Fat Free Vanilla Yogurt",
#             "price": "\u00a31.00",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910000470969",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a31.25",
#             "brandName": "Onken",
#             "promoType": "Rollback",
#             "weight": "450g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "7610900037414",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.7143",
#             "name": "Onken Fat Free Vanilla Yogurt",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910000470969",
#             "pricePerUOM": "",
#             "searchTuningScore": "2129404.5",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000977060",
#             "shelfName": "Fat Free & Low Fat",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a33.5::true",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6346374",
#             "promoDetailFull": "10 for \u00a33.5",
#             "availability": "A",
#             "totalReviewCount": "22",
#             "asdaSuggest": "",
#             "itemName": "Fat Free Limited Edition Yogurt",
#             "price": "\u00a30.55",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000116808405",
#             "promoId": "ls91195",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Light",
#             "promoType": "No Promo",
#             "weight": "160g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a33.50",
#             "productAttribute": "",
#             "scene7AssetId": "4025500243715",
#             "promoDetail": "10 for \u00a33.5",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "2.5",
#             "name": "Muller Light Fat Free Limited Edition Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000116808405",
#             "pricePerUOM": "",
#             "searchTuningScore": "2041078.0",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215287321995",
#             "shelfName": "Luxury",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "2::for::\u00a31::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "4223022",
#             "promoDetailFull": "2 for \u00a31",
#             "availability": "A",
#             "totalReviewCount": "36",
#             "asdaSuggest": "",
#             "itemName": "Lemon Yogurt",
#             "price": "\u00a30.60",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910001008981",
#             "promoId": "ls91334",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "ASDA Extra Special",
#             "promoType": "No Promo",
#             "weight": "150g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "2",
#             "promoValue": "\u00a31",
#             "productAttribute": "",
#             "scene7AssetId": "5052449782400",
#             "promoDetail": "2 for \u00a31",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.9167",
#             "name": "ASDA Extra Special Lemon Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "49300003",
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910001008981",
#             "pricePerUOM": "",
#             "searchTuningScore": "1959208.4",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000976118",
#             "shelfName": "Big Pots",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "3689732",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "40",
#             "asdaSuggest": "",
#             "itemName": "Cherry Yogurt",
#             "price": "\u00a31.00",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910000470865",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a31.25",
#             "brandName": "Onken",
#             "promoType": "Rollback",
#             "weight": "450g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "7610900037346",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.775",
#             "name": "Onken Cherry Yogurt",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910000470865",
#             "pricePerUOM": "",
#             "searchTuningScore": "1712342.8",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215639963408",
#             "shelfName": "Greek Style",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "4027153",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "30",
#             "asdaSuggest": "",
#             "itemName": "Fat Free Greek Style Lemon Yogurts",
#             "price": "\u00a31.25",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910000858813",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a31.75",
#             "brandName": "Muller Light",
#             "promoType": "Rollback",
#             "weight": "4x120g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "4025500169442",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.4",
#             "name": "Muller Light Fat Free Greek Style Lemon Yogurts",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910000858813",
#             "pricePerUOM": "",
#             "searchTuningScore": "1590507.6",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000977060",
#             "shelfName": "Fat Free & Low Fat",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "4::for::\u00a33::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "5033896",
#             "promoDetailFull": "4 for \u00a33",
#             "availability": "A",
#             "totalReviewCount": "19",
#             "asdaSuggest": "",
#             "itemName": "Strawberry Yogurt",
#             "price": "\u00a30.98",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910001812876",
#             "promoId": "ls90172",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Arla Protein",
#             "promoType": "No Promo",
#             "weight": "200g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "4",
#             "promoValue": "\u00a33",
#             "productAttribute": "",
#             "scene7AssetId": "6413300018042",
#             "promoDetail": "4 for \u00a33",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "2.8947",
#             "name": "Arla Protein Strawberry Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "49100001"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910001812876",
#             "pricePerUOM": "",
#             "searchTuningScore": "1500793.1",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215287321995",
#             "shelfName": "Luxury",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "2::for::\u00a31::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "4223020",
#             "promoDetailFull": "2 for \u00a31",
#             "availability": "A",
#             "totalReviewCount": "11",
#             "asdaSuggest": "",
#             "itemName": "Strawberry Yogurt",
#             "price": "\u00a30.60",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910001009596",
#             "promoId": "ls91334",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "ASDA Extra Special",
#             "promoType": "No Promo",
#             "weight": "150g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "2",
#             "promoValue": "\u00a31",
#             "productAttribute": "",
#             "scene7AssetId": "5052449782394",
#             "promoDetail": "2 for \u00a31",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "5.0",
#             "name": "ASDA Extra Special Strawberry Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910001009596",
#             "pricePerUOM": "",
#             "searchTuningScore": "1469406.2",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286423096",
#             "shelfName": "Activia Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "4::for::\u00a33::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6513082",
#             "promoDetailFull": "4 for \u00a33",
#             "availability": "A",
#             "totalReviewCount": "64",
#             "asdaSuggest": "",
#             "itemName": "Low Fat Yogurt Raspberry & Chia Seed Muesli",
#             "price": "\u00a30.90",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000161156362",
#             "promoId": "ls90172",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Activia",
#             "promoType": "No Promo",
#             "weight": "165g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "4",
#             "promoValue": "\u00a33",
#             "productAttribute": "",
#             "scene7AssetId": "5060360504360",
#             "promoDetail": "4 for \u00a33",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.6719",
#             "name": "Activia Low Fat Yogurt Raspberry & Chia Seed Muesli",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000161156362",
#             "pricePerUOM": "",
#             "searchTuningScore": "1468876.8",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215639299553",
#             "shelfName": "M\u00fcller Rice",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a33.5::true",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "4714073",
#             "promoDetailFull": "10 for \u00a33.5",
#             "availability": "A",
#             "totalReviewCount": "13",
#             "asdaSuggest": "",
#             "itemName": "Strawberry Low Fat Dessert",
#             "price": "\u00a30.55",
#             "imageURL": "",
#             "aisleName": "Desserts",
#             "id": "910001390057",
#             "promoId": "ls91195",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Rice",
#             "promoType": "No Promo",
#             "weight": "1x180g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a33.50",
#             "productAttribute": "",
#             "scene7AssetId": "4025500183509",
#             "promoDetail": "10 for \u00a33.5",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "5.0",
#             "name": "Muller Rice Strawberry Low Fat Dessert",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910001390057",
#             "pricePerUOM": "",
#             "searchTuningScore": "1283662.5",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215640038591",
#             "shelfName": "High In Protein",
#             "deptId": "1215341888021",
# ...
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "ASDA",
#             "promoType": "No Promo",
#             "weight": "6x60g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "2",
#             "promoValue": "\u00a32",
#             "productAttribute": "",
#             "scene7AssetId": "5054070225677",
#             "promoDetail": "2 for \u00a32",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "3.6875",
#             "name": "ASDA Chocolate Mousses",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910001410157",
#             "pricePerUOM": "",
#             "searchTuningScore": "201507.39",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215640038591",
#             "shelfName": "High In Protein",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "4::for::\u00a33::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6210808",
#             "promoDetailFull": "4 for \u00a33",
#             "availability": "A",
#             "totalReviewCount": "15",
#             "asdaSuggest": "",
#             "itemName": "Kvarg Stracciatella",
#             "price": "\u00a30.89",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000080993840",
#             "promoId": "ls90172",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Lindahls",
#             "promoType": "No Promo",
#             "weight": "150g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "4",
#             "promoValue": "\u00a33",
#             "productAttribute": "",
#             "scene7AssetId": "3023290025338",
#             "promoDetail": "4 for \u00a33",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "3.7333",
#             "name": "Lindahls Kvarg Stracciatella",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600051"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000080993840",
#             "pricePerUOM": "",
#             "searchTuningScore": "173175.4",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215639170517",
#             "shelfName": "Chocolate & Caramel Desserts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "5::for::\u00a33::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6510885",
#             "promoDetailFull": "5 for \u00a33",
#             "availability": "A",
#             "totalReviewCount": "1",
#             "asdaSuggest": "",
#             "itemName": "Dairy Milk Chunks Chocolate Dessert",
#             "price": "\u00a30.75",
#             "imageURL": "",
#             "aisleName": "Desserts",
#             "id": "1000160202778",
#             "promoId": "ls91344",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Cadbury",
#             "promoType": "No Promo",
#             "weight": "85g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "5",
#             "promoValue": "\u00a33",
#             "productAttribute": "",
#             "scene7AssetId": "4025500252120",
#             "promoDetail": "5 for \u00a33",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "5.0",
#             "name": "Cadbury Dairy Milk Chunks Chocolate Dessert",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600048"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000160202778",
#             "pricePerUOM": "",
#             "searchTuningScore": "151265.36",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215639170517",
#             "shelfName": "Chocolate & Caramel Desserts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6484098",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "22",
#             "asdaSuggest": "",
#             "itemName": "Low Fat Chocolate Fix Belgian Chocolate Dessert",
#             "price": "\u00a31.00",
#             "imageURL": "",
#             "aisleName": "Desserts",
#             "id": "1000151138601",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a32.00",
#             "brandName": "Muller Light",
#             "promoType": "Rollback",
#             "weight": "4x100g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "4025500175221",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.7273",
#             "name": "Muller Light Low Fat Chocolate Fix Belgian Chocolate Dessert",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000151138601",
#             "pricePerUOM": "",
#             "searchTuningScore": "148333.86",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215639198219",
#             "shelfName": "Mousse",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "1764156",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "14",
#             "asdaSuggest": "",
#             "itemName": "Milk Chocolate Mousse",
#             "price": "\u00a31.00",
#             "imageURL": "",
#             "aisleName": "Desserts",
#             "id": "12825052",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a31.40",
#             "brandName": "Aero",
#             "promoType": "Rollback",
#             "weight": "4x59g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "3023290624012",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.7143",
#             "name": "Aero Milk Chocolate Mousse",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600051"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=12825052",
#             "pricePerUOM": "",
#             "searchTuningScore": "136884.03",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215639170517",
#             "shelfName": "Chocolate & Caramel Desserts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "5::for::\u00a33::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6714207",
#             "promoDetailFull": "5 for \u00a33",
#             "availability": "A",
#             "totalReviewCount": "3",
#             "asdaSuggest": "",
#             "itemName": "Dairy Milk Daim Chocolate Dessert",
#             "price": "\u00a30.75",
#             "imageURL": "",
#             "aisleName": "Desserts",
#             "id": "1000216902774",
#             "promoId": "ls91344",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Cadbury",
#             "promoType": "No Promo",
#             "weight": "85g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "5",
#             "promoValue": "\u00a33",
#             "productAttribute": "",
#             "scene7AssetId": "4025500252144",
#             "promoDetail": "5 for \u00a33",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.3333",
#             "name": "Cadbury Dairy Milk Daim Chocolate Dessert",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600048"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000216902774",
#             "pricePerUOM": "",
#             "searchTuningScore": "98498.375",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000977060",
#             "shelfName": "Fat Free & Low Fat",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "2::for::\u00a34.50::true",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6587681",
#             "promoDetailFull": "2 for \u00a34.50",
#             "availability": "A",
#             "totalReviewCount": "58",
#             "asdaSuggest": "",
#             "itemName": "Strawberry & Cherry Yogurts",
#             "price": "\u00a33.00",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000184511950",
#             "promoId": "ls90380",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Benecol",
#             "promoType": "No Promo",
#             "weight": "4x120",
#             "promoOfferTypeCode": "15",
#             "promoQty": "2",
#             "promoValue": "\u00a34.50",
#             "productAttribute": "",
#             "scene7AssetId": "5055940101497",
#             "promoDetail": "2 for \u00a34.50",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.3621",
#             "name": "Benecol Strawberry & Cherry Yogurts",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000184511950",
#             "pricePerUOM": "",
#             "searchTuningScore": "3851.9917",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         }
#     ],
#     "facets": [
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Chilled Food",
#             "displayName": "Chilled Food",
#             "itemCount": "338"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Free From...",
#             "displayName": "Free From...",
#             "itemCount": "20"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Food Cupboard",
#             "displayName": "Food Cupboard",
#             "itemCount": "19"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Fresh Food & Bakery",
#             "displayName": "Fresh Food & Bakery",
#             "itemCount": "15"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Baby, Toddler & Kids",
#             "displayName": "Baby, Toddler & Kids",
#             "itemCount": "9"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:World & Local Food",
#             "displayName": "World & Local Food",
#             "itemCount": "7"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Health & Beauty",
#             "displayName": "Health & Beauty",
#             "itemCount": "3"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Frozen Food",
#             "displayName": "Frozen Food",
#             "itemCount": "1"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Pet Food & Accessories",
#             "displayName": "Pet Food & Accessories",
#             "itemCount": "1"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:ASDA",
#             "displayName": "ASDA",
#             "itemCount": "75"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Muller Light",
#             "displayName": "Muller Light",
#             "itemCount": "15"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Actimel",
#             "displayName": "Actimel",
#             "itemCount": "14"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Activia",
#             "displayName": "Activia",
#             "itemCount": "14"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:ASDA Extra Special",
#             "displayName": "ASDA Extra Special",
#             "itemCount": "12"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Cadbury",
#             "displayName": "Cadbury",
#             "itemCount": "12"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Muller Corner",
#             "displayName": "Muller Corner",
#             "itemCount": "12"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Lindahls",
#             "displayName": "Lindahls",
#             "itemCount": "11"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:GU",
#             "displayName": "GU",
#             "itemCount": "10"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Yazoo",
#             "displayName": "Yazoo",
#             "itemCount": "10"
#         }
#     ],
#     "mediaContent": "",
#     "useKeywordAsIcon": "",
#     "processTime": 40,
#     "statusCode": "0"
# }

# %%
# Exercise 2.2.  Another way to pass parameters

parameters = {'keyword': 'yogurt', 
              'r': 'json'}

r=requests.get('https://groceries.asda.com/api/items/search', params=parameters)

# in case authentication is needed, use
# r = requests.get('https://api.github.com/user', \
# auth=('user', 'pass'))

# if the API call returns a successful response
if r.status_code==200:
    
    # This API call returns a json object
    # r.json() gives the json object
    print (json.dumps(r.json(), indent=4))
# Out:
# {
#     "statusMessage": "The API Item Search was executed successfully",
#     "errors": [],
#     "keyword": "yogurt",
#     "storeId": "4565",
#     "autoCorrectedTerm": "",
#     "didYouMeanTerm": "",
#     "isHookLogicInsert": "false",
#     "totalResult": "413",
#     "currentPage": "1",
#     "resultsStartIndex": "1",
#     "resultsEndIndex": "60",
#     "maxPages": "7",
#     "qusApplied": false,
#     "productBoostingDetails": "0^rule_5f8046bf0931946b86fb4387^^^Default",
#     "monetizedItems": [],
#     "items": [
#         {
#             "shelfId": "1215286383583",
#             "shelfName": "Corners",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a33.5::true",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6362225",
#             "promoDetailFull": "10 for \u00a33.5",
#             "availability": "A",
#             "totalReviewCount": "8",
#             "asdaSuggest": "",
#             "itemName": "Vanilla Yogurt with Chocolate\u00a0Balls",
#             "price": "\u00a30.55",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000120228362",
#             "promoId": "ls91195",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Corner",
#             "promoType": "No Promo",
#             "weight": "130g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a33.50",
#             "productAttribute": "",
#             "scene7AssetId": "4025500245221",
#             "promoDetail": "10 for \u00a33.5",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.625",
#             "name": "Muller Corner Vanilla Yogurt with Chocolate\u00a0Balls",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000120228362",
#             "pricePerUOM": "",
#             "searchTuningScore": "1.869282E7",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286383583",
#             "shelfName": "Corners",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a33.5::true",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6362239",
#             "promoDetailFull": "10 for \u00a33.5",
#             "availability": "A",
#             "totalReviewCount": "3",
#             "asdaSuggest": "",
#             "itemName": "Strawberry Yogurt",
#             "price": "\u00a30.55",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000120228322",
#             "promoId": "ls91195",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Corner",
#             "promoType": "No Promo",
#             "weight": "143g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a33.50",
#             "productAttribute": "",
#             "scene7AssetId": "4025500245092",
#             "promoDetail": "10 for \u00a33.5",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "3.6667",
#             "name": "Muller Corner Strawberry Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000120228322",
#             "pricePerUOM": "",
#             "searchTuningScore": "1.3473809E7",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286383583",
#             "shelfName": "Corners",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a33.5::true",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6362227",
#             "promoDetailFull": "10 for \u00a33.5",
#             "availability": "A",
#             "totalReviewCount": "9",
#             "asdaSuggest": "",
#             "itemName": "Banana Yogurt with Chocolate Flakes",
#             "price": "\u00a30.55",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000120228335",
#             "promoId": "ls91195",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Corner",
#             "promoType": "No Promo",
#             "weight": "130g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a33.50",
#             "productAttribute": "",
#             "scene7AssetId": "4025500245207",
#             "promoDetail": "10 for \u00a33.5",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "3.6667",
#             "name": "Muller Corner Banana Yogurt with Chocolate Flakes",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000120228335",
#             "pricePerUOM": "",
#             "searchTuningScore": "1.2041251E7",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286383583",
#             "shelfName": "Corners",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a33.5::true",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6362229",
#             "promoDetailFull": "10 for \u00a33.5",
#             "availability": "A",
#             "totalReviewCount": "8",
#             "asdaSuggest": "",
#             "itemName": "Toffee Yogurt with Chocolate Hoops",
#             "price": "\u00a30.55",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000120228313",
#             "promoId": "ls91195",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Corner",
#             "promoType": "No Promo",
#             "weight": "130g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a33.50",
#             "productAttribute": "",
#             "scene7AssetId": "4025500245146",
#             "promoDetail": "10 for \u00a33.5",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "3.75",
#             "name": "Muller Corner Toffee Yogurt with Chocolate Hoops",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000120228313",
#             "pricePerUOM": "",
#             "searchTuningScore": "8325497.0",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286383583",
#             "shelfName": "Corners",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a33.5::true",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6362233",
#             "promoDetailFull": "10 for \u00a33.5",
#             "availability": "A",
#             "totalReviewCount": "10",
#             "asdaSuggest": "",
#             "itemName": "Strawberry Yogurt with White Chocolate Shortcake Balls",
#             "price": "\u00a30.55",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000120228351",
#             "promoId": "ls91195",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Corner",
#             "promoType": "No Promo",
#             "weight": "130g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a33.50",
#             "productAttribute": "",
#             "scene7AssetId": "4025500245160",
#             "promoDetail": "10 for \u00a33.5",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "3.8",
#             "name": "Muller Corner Strawberry Yogurt with White Chocolate Shortcake Balls",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000120228351",
#             "pricePerUOM": "",
#             "searchTuningScore": "7703160.0",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000977060",
#             "shelfName": "Fat Free & Low Fat",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a33.5::true",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6346362",
#             "promoDetailFull": "10 for \u00a33.5",
#             "availability": "A",
#             "totalReviewCount": "8",
#             "asdaSuggest": "",
#             "itemName": "Fat Free Toffee Yogurt",
#             "price": "\u00a30.55",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000116808315",
#             "promoId": "ls91195",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Light",
#             "promoType": "No Promo",
#             "weight": "160g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a33.50",
#             "productAttribute": "",
#             "scene7AssetId": "4025500243579",
#             "promoDetail": "10 for \u00a33.5",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.5",
#             "name": "Muller Light Fat Free Toffee Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000116808315",
#             "pricePerUOM": "",
#             "searchTuningScore": "7371434.5",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286423096",
#             "shelfName": "Activia Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "4::for::\u00a33::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6202233",
#             "promoDetailFull": "4 for \u00a33",
#             "availability": "A",
#             "totalReviewCount": "38",
#             "asdaSuggest": "",
#             "itemName": "Low Fat Vanilla Yogurt & Granola",
#             "price": "\u00a30.90",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000078311452",
#             "promoId": "ls90172",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Activia",
#             "promoType": "No Promo",
#             "weight": "165g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "4",
#             "promoValue": "\u00a33",
#             "productAttribute": "",
#             "scene7AssetId": "5060360502960",
#             "promoDetail": "4 for \u00a33",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.4211",
#             "name": "Activia Low Fat Vanilla Yogurt & Granola",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000078311452",
#             "pricePerUOM": "",
#             "searchTuningScore": "6340794.5",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000977060",
#             "shelfName": "Fat Free & Low Fat",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a33.5::true",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6346360",
#             "promoDetailFull": "10 for \u00a33.5",
#             "availability": "A",
#             "totalReviewCount": "10",
#             "asdaSuggest": "",
#             "itemName": "Fat Free Banana and Custard Yogurt",
#             "price": "\u00a30.55",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000116808339",
#             "promoId": "ls91195",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Light",
#             "promoType": "No Promo",
#             "weight": "160g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a33.50",
#             "productAttribute": "",
#             "scene7AssetId": "4025500243555",
#             "promoDetail": "10 for \u00a33.5",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.1",
#             "name": "Muller Light Fat Free Banana and Custard Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000116808339",
#             "pricePerUOM": "",
#             "searchTuningScore": "5353415.5",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000977060",
#             "shelfName": "Fat Free & Low Fat",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a33.5::true",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6346354",
#             "promoDetailFull": "10 for \u00a33.5",
#             "availability": "A",
#             "totalReviewCount": "7",
#             "asdaSuggest": "",
#             "itemName": "Fat Free Strawberry Yogurt",
#             "price": "\u00a30.55",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000116808369",
#             "promoId": "ls91195",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Light",
#             "promoType": "No Promo",
#             "weight": "160g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a33.50",
#             "productAttribute": "",
#             "scene7AssetId": "4025500243357",
#             "promoDetail": "10 for \u00a33.5",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.2857",
#             "name": "Muller Light Fat Free Strawberry Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000116808369",
#             "pricePerUOM": "",
#             "searchTuningScore": "5169195.5",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286423096",
#             "shelfName": "Activia Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "4582588",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "50",
#             "asdaSuggest": "",
#             "itemName": "Intensely Creamy Strawberry Yogurts",
#             "price": "\u00a31.25",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910001285499",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a32.00",
#             "brandName": "Activia",
#             "promoType": "Rollback",
#             "weight": "4x110g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5060360500003",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.46",
#             "name": "Activia Intensely Creamy Strawberry Yogurts",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910001285499",
#             "pricePerUOM": "",
#             "searchTuningScore": "5081264.5",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286423096",
#             "shelfName": "Activia Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "4582592",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "12",
#             "asdaSuggest": "",
#             "itemName": "Intensely Creamy Cherry Yogurts",
#             "price": "\u00a31.25",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910001285443",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a32.00",
#             "brandName": "Activia",
#             "promoType": "Rollback",
#             "weight": "4x110g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5060360500027",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.75",
#             "name": "Activia Intensely Creamy Cherry Yogurts",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910001285443",
#             "pricePerUOM": "",
#             "searchTuningScore": "3844005.0",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000977060",
#             "shelfName": "Fat Free & Low Fat",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a33.5::true",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6346366",
#             "promoDetailFull": "10 for \u00a33.5",
#             "availability": "A",
#             "totalReviewCount": "9",
#             "asdaSuggest": "",
#             "itemName": "Fat Free Vanilla & Dark Chocolate Yogurt",
#             "price": "\u00a30.55",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000116808389",
#             "promoId": "ls91195",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Light",
#             "promoType": "No Promo",
#             "weight": "160g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a33.50",
#             "productAttribute": "",
#             "scene7AssetId": "4025500243616",
#             "promoDetail": "10 for \u00a33.5",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.5556",
#             "name": "Muller Light Fat Free Vanilla & Dark Chocolate Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000116808389",
#             "pricePerUOM": "",
#             "searchTuningScore": "3490875.5",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000976118",
#             "shelfName": "Big Pots",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "3689730",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "56",
#             "asdaSuggest": "",
#             "itemName": "Mango, Papaya & Passion Fruit Yogurt",
#             "price": "\u00a31.00",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910000470832",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a31.25",
#             "brandName": "Onken",
#             "promoType": "Rollback",
#             "weight": "450g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "7610900037360",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.7857",
#             "name": "Onken Mango, Papaya & Passion Fruit Yogurt",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910000470832",
#             "pricePerUOM": "",
#             "searchTuningScore": "3108602.8",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286423096",
#             "shelfName": "Activia Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "4582596",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "50",
#             "asdaSuggest": "",
#             "itemName": "Intensely Creamy Peach Yogurts",
#             "price": "\u00a31.25",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910001285082",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a32.00",
#             "brandName": "Activia",
#             "promoType": "Rollback",
#             "weight": "4x110g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5060360500041",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.76",
#             "name": "Activia Intensely Creamy Peach Yogurts",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910001285082",
#             "pricePerUOM": "",
#             "searchTuningScore": "2918421.5",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000976085",
#             "shelfName": "Kids Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "4786440",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "51",
#             "asdaSuggest": "",
#             "itemName": "Apricot, Strawberry & Raspberry Yogurt",
#             "price": "\u00a32.00",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910001458433",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a33.00",
#             "brandName": "Petits Filous",
#             "promoType": "Rollback",
#             "weight": "18x47g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "3329770051621",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.4706",
#             "name": "Petits Filous Apricot, Strawberry & Raspberry Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600050"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910001458433",
#             "pricePerUOM": "",
#             "searchTuningScore": "2788633.8",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000976118",
#             "shelfName": "Big Pots",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "3689722",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "37",
#             "asdaSuggest": "",
#             "itemName": "Fat Free Strawberry Yogurt",
#             "price": "\u00a31.00",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910000470905",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a31.25",
#             "brandName": "Onken",
#             "promoType": "Rollback",
#             "weight": "450g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "7610900037421",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.8108",
#             "name": "Onken Fat Free Strawberry Yogurt",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910000470905",
#             "pricePerUOM": "",
#             "searchTuningScore": "2450505.2",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000977060",
#             "shelfName": "Fat Free & Low Fat",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a33.5::true",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6346374",
#             "promoDetailFull": "10 for \u00a33.5",
#             "availability": "A",
#             "totalReviewCount": "22",
#             "asdaSuggest": "",
#             "itemName": "Fat Free Limited Edition Yogurt",
#             "price": "\u00a30.55",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000116808405",
#             "promoId": "ls91195",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Light",
#             "promoType": "No Promo",
#             "weight": "160g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a33.50",
#             "productAttribute": "",
#             "scene7AssetId": "4025500243715",
#             "promoDetail": "10 for \u00a33.5",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "2.5",
#             "name": "Muller Light Fat Free Limited Edition Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000116808405",
#             "pricePerUOM": "",
#             "searchTuningScore": "2041078.0",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215287321995",
#             "shelfName": "Luxury",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "2::for::\u00a31::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "4223022",
#             "promoDetailFull": "2 for \u00a31",
#             "availability": "A",
#             "totalReviewCount": "36",
#             "asdaSuggest": "",
#             "itemName": "Lemon Yogurt",
#             "price": "\u00a30.60",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910001008981",
#             "promoId": "ls91334",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "ASDA Extra Special",
#             "promoType": "No Promo",
#             "weight": "150g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "2",
#             "promoValue": "\u00a31",
#             "productAttribute": "",
#             "scene7AssetId": "5052449782400",
#             "promoDetail": "2 for \u00a31",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.9167",
#             "name": "ASDA Extra Special Lemon Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "49300003",
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910001008981",
#             "pricePerUOM": "",
#             "searchTuningScore": "1959208.4",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000976118",
#             "shelfName": "Big Pots",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "3689732",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "40",
#             "asdaSuggest": "",
#             "itemName": "Cherry Yogurt",
#             "price": "\u00a31.00",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910000470865",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a31.25",
#             "brandName": "Onken",
#             "promoType": "Rollback",
#             "weight": "450g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "7610900037346",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.775",
#             "name": "Onken Cherry Yogurt",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910000470865",
#             "pricePerUOM": "",
#             "searchTuningScore": "1712342.8",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215639963408",
#             "shelfName": "Greek Style",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "4027153",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "30",
#             "asdaSuggest": "",
#             "itemName": "Fat Free Greek Style Lemon Yogurts",
#             "price": "\u00a31.25",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910000858813",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a31.75",
#             "brandName": "Muller Light",
#             "promoType": "Rollback",
#             "weight": "4x120g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "4025500169442",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.4",
#             "name": "Muller Light Fat Free Greek Style Lemon Yogurts",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910000858813",
#             "pricePerUOM": "",
#             "searchTuningScore": "1590507.6",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000977060",
#             "shelfName": "Fat Free & Low Fat",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "4::for::\u00a33::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "5033896",
#             "promoDetailFull": "4 for \u00a33",
#             "availability": "A",
#             "totalReviewCount": "19",
#             "asdaSuggest": "",
#             "itemName": "Strawberry Yogurt",
#             "price": "\u00a30.98",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910001812876",
#             "promoId": "ls90172",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Arla Protein",
#             "promoType": "No Promo",
#             "weight": "200g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "4",
#             "promoValue": "\u00a33",
#             "productAttribute": "",
#             "scene7AssetId": "6413300018042",
#             "promoDetail": "4 for \u00a33",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "2.8947",
#             "name": "Arla Protein Strawberry Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "49100001"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910001812876",
#             "pricePerUOM": "",
#             "searchTuningScore": "1500793.1",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215287321995",
#             "shelfName": "Luxury",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "2::for::\u00a31::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "4223020",
#             "promoDetailFull": "2 for \u00a31",
#             "availability": "A",
#             "totalReviewCount": "11",
#             "asdaSuggest": "",
#             "itemName": "Strawberry Yogurt",
#             "price": "\u00a30.60",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910001009596",
#             "promoId": "ls91334",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "ASDA Extra Special",
#             "promoType": "No Promo",
#             "weight": "150g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "2",
#             "promoValue": "\u00a31",
#             "productAttribute": "",
#             "scene7AssetId": "5052449782394",
#             "promoDetail": "2 for \u00a31",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "5.0",
#             "name": "ASDA Extra Special Strawberry Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910001009596",
#             "pricePerUOM": "",
#             "searchTuningScore": "1469406.2",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215639299553",
#             "shelfName": "M\u00fcller Rice",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a33.5::true",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "4714073",
#             "promoDetailFull": "10 for \u00a33.5",
#             "availability": "A",
#             "totalReviewCount": "13",
#             "asdaSuggest": "",
#             "itemName": "Strawberry Low Fat Dessert",
#             "price": "\u00a30.55",
#             "imageURL": "",
#             "aisleName": "Desserts",
#             "id": "910001390057",
#             "promoId": "ls91195",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Rice",
#             "promoType": "No Promo",
#             "weight": "1x180g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a33.50",
#             "productAttribute": "",
#             "scene7AssetId": "4025500183509",
#             "promoDetail": "10 for \u00a33.5",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "5.0",
#             "name": "Muller Rice Strawberry Low Fat Dessert",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910001390057",
#             "pricePerUOM": "",
#             "searchTuningScore": "1283662.5",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215640038591",
#             "shelfName": "High In Protein",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "4::for::\u00a33::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "5033892",
#             "promoDetailFull": "4 for \u00a33",
#             "availability": "A",
#             "totalReviewCount": "17",
#             "asdaSuggest": "",
#             "itemName": "Blueberry Yogurt",
#             "price": "\u00a30.98",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910001812976",
#             "promoId": "ls90172",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Arla Protein",
#             "promoType": "No Promo",
#             "weight": "200g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "4",
#             "promoValue": "\u00a33",
#             "productAttribute": "",
#             "scene7AssetId": "6413300018028",
#             "promoDetail": "4 for \u00a33",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "3.6471",
#             "name": "Arla Protein Blueberry Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "49100001"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910001812976",
#             "pricePerUOM": "",
#             "searchTuningScore": "1099446.2",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215287321995",
#             "shelfName": "Luxury",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "2::for::\u00a31::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "4223008",
#             "promoDetailFull": "2 for \u00a31",
#             "availability": "A",
#             "totalReviewCount": "11",
#             "asdaSuggest": "",
#             "itemName": "Fudge Yogurt",
#             "price": "\u00a30.60",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910001009649",
#             "promoId": "ls91334",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "ASDA Extra Special",
#             "promoType": "No Promo",
#             "weight": "150g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "2",
#             "promoValue": "\u00a31",
#             "productAttribute": "",
#             "scene7AssetId": "5052449782356",
#             "promoDetail": "2 for \u00a31",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.3636",
#             "name": "ASDA Extra Special Fudge Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910001009649",
#             "pricePerUOM": "",
#             "searchTuningScore": "995796.0",
# ...
#             "id": "1429710",
#             "promoId": "ls91343",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Actimel",
#             "promoType": "No Promo",
#             "weight": "8x100g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "2",
#             "promoValue": "\u00a34",
#             "productAttribute": "",
#             "scene7AssetId": "5016769993724",
#             "promoDetail": "2 for \u00a34",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.6595",
#             "name": "Actimel Multifruit Yogurt Drinks",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1429710",
#             "pricePerUOM": "",
#             "searchTuningScore": "244192.67",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215639170517",
#             "shelfName": "Chocolate & Caramel Desserts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6484100",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "23",
#             "asdaSuggest": "",
#             "itemName": "Low Fat Chocolate Fix Belgian Chocolate & Caramel Dessert",
#             "price": "\u00a31.00",
#             "imageURL": "",
#             "aisleName": "Desserts",
#             "id": "1000151138622",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a32.00",
#             "brandName": "Muller Light",
#             "promoType": "Rollback",
#             "weight": "4x80g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "4025500189532",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "3.913",
#             "name": "Muller Light Low Fat Chocolate Fix Belgian Chocolate & Caramel Dessert",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000151138622",
#             "pricePerUOM": "",
#             "searchTuningScore": "216930.95",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215639198219",
#             "shelfName": "Mousse",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "2::for::\u00a32::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "4735061",
#             "promoDetailFull": "2 for \u00a32",
#             "availability": "A",
#             "totalReviewCount": "32",
#             "asdaSuggest": "",
#             "itemName": "Chocolate Mousses",
#             "price": "\u00a31.15",
#             "imageURL": "",
#             "aisleName": "Desserts",
#             "id": "910001410157",
#             "promoId": "ls91359",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "ASDA",
#             "promoType": "No Promo",
#             "weight": "6x60g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "2",
#             "promoValue": "\u00a32",
#             "productAttribute": "",
#             "scene7AssetId": "5054070225677",
#             "promoDetail": "2 for \u00a32",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "3.6875",
#             "name": "ASDA Chocolate Mousses",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910001410157",
#             "pricePerUOM": "",
#             "searchTuningScore": "201507.39",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215640038591",
#             "shelfName": "High In Protein",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "4::for::\u00a33::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6210808",
#             "promoDetailFull": "4 for \u00a33",
#             "availability": "A",
#             "totalReviewCount": "15",
#             "asdaSuggest": "",
#             "itemName": "Kvarg Stracciatella",
#             "price": "\u00a30.89",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000080993840",
#             "promoId": "ls90172",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Lindahls",
#             "promoType": "No Promo",
#             "weight": "150g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "4",
#             "promoValue": "\u00a33",
#             "productAttribute": "",
#             "scene7AssetId": "3023290025338",
#             "promoDetail": "4 for \u00a33",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "3.7333",
#             "name": "Lindahls Kvarg Stracciatella",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600051"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000080993840",
#             "pricePerUOM": "",
#             "searchTuningScore": "173175.4",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215639170517",
#             "shelfName": "Chocolate & Caramel Desserts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "5::for::\u00a33::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6510885",
#             "promoDetailFull": "5 for \u00a33",
#             "availability": "A",
#             "totalReviewCount": "1",
#             "asdaSuggest": "",
#             "itemName": "Dairy Milk Chunks Chocolate Dessert",
#             "price": "\u00a30.75",
#             "imageURL": "",
#             "aisleName": "Desserts",
#             "id": "1000160202778",
#             "promoId": "ls91344",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Cadbury",
#             "promoType": "No Promo",
#             "weight": "85g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "5",
#             "promoValue": "\u00a33",
#             "productAttribute": "",
#             "scene7AssetId": "4025500252120",
#             "promoDetail": "5 for \u00a33",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "5.0",
#             "name": "Cadbury Dairy Milk Chunks Chocolate Dessert",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600048"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000160202778",
#             "pricePerUOM": "",
#             "searchTuningScore": "151265.36",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215639170517",
#             "shelfName": "Chocolate & Caramel Desserts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6484098",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "22",
#             "asdaSuggest": "",
#             "itemName": "Low Fat Chocolate Fix Belgian Chocolate Dessert",
#             "price": "\u00a31.00",
#             "imageURL": "",
#             "aisleName": "Desserts",
#             "id": "1000151138601",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a32.00",
#             "brandName": "Muller Light",
#             "promoType": "Rollback",
#             "weight": "4x100g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "4025500175221",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.7273",
#             "name": "Muller Light Low Fat Chocolate Fix Belgian Chocolate Dessert",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000151138601",
#             "pricePerUOM": "",
#             "searchTuningScore": "148333.86",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215639198219",
#             "shelfName": "Mousse",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "1764156",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "14",
#             "asdaSuggest": "",
#             "itemName": "Milk Chocolate Mousse",
#             "price": "\u00a31.00",
#             "imageURL": "",
#             "aisleName": "Desserts",
#             "id": "12825052",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a31.40",
#             "brandName": "Aero",
#             "promoType": "Rollback",
#             "weight": "4x59g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "3023290624012",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.7143",
#             "name": "Aero Milk Chocolate Mousse",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600051"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=12825052",
#             "pricePerUOM": "",
#             "searchTuningScore": "136884.03",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         }
#     ],
#     "facets": [
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Chilled Food",
#             "displayName": "Chilled Food",
#             "itemCount": "338"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Free From...",
#             "displayName": "Free From...",
#             "itemCount": "20"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Food Cupboard",
#             "displayName": "Food Cupboard",
#             "itemCount": "19"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Fresh Food & Bakery",
#             "displayName": "Fresh Food & Bakery",
#             "itemCount": "15"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Baby, Toddler & Kids",
#             "displayName": "Baby, Toddler & Kids",
#             "itemCount": "9"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:World & Local Food",
#             "displayName": "World & Local Food",
#             "itemCount": "7"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Health & Beauty",
#             "displayName": "Health & Beauty",
#             "itemCount": "3"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Frozen Food",
#             "displayName": "Frozen Food",
#             "itemCount": "1"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Pet Food & Accessories",
#             "displayName": "Pet Food & Accessories",
#             "itemCount": "1"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:ASDA",
#             "displayName": "ASDA",
#             "itemCount": "75"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Muller Light",
#             "displayName": "Muller Light",
#             "itemCount": "15"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Actimel",
#             "displayName": "Actimel",
#             "itemCount": "14"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Activia",
#             "displayName": "Activia",
#             "itemCount": "14"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:ASDA Extra Special",
#             "displayName": "ASDA Extra Special",
#             "itemCount": "12"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Cadbury",
#             "displayName": "Cadbury",
#             "itemCount": "12"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Muller Corner",
#             "displayName": "Muller Corner",
#             "itemCount": "12"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Lindahls",
#             "displayName": "Lindahls",
#             "itemCount": "11"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:GU",
#             "displayName": "GU",
#             "itemCount": "10"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Yazoo",
#             "displayName": "Yazoo",
#             "itemCount": "10"
#         }
#     ],
#     "mediaContent": "",
#     "useKeywordAsIcon": "",
#     "processTime": 52,
#     "statusCode": "0"
# }

# %% [markdown]
# ## 3. JSON (JavaScript Object Notation)
#
# ### What is JSON
# - A lightweight data-interchange format
# - "Self-describing" and easy to understand
# - JSON format is text only
# - Language independent: can be read and used as a data format by any programming language
#
# ###  JSON Syntax Rules
# JSON syntax is derived from JavaScript object notation syntax:
# - Data is in **name/value** pairs separated by commas
# - Curly braces hold objects
# - Square brackets hold arrays
#
# ### A JSON object is:
# - **a dictionary** or
# - a **list of dictionaries**
#
# ### Useful JSON functions
# - dumps: save json object to string
# - dump: save json object to file
# - loads: load from a string in json format
# - load: load from a file in json format

# %%
# Exercise 3.1 API returns a JSON object 

parameters = {'keyword': 'yogurt', 
              'r': 'json'}

r=requests.get('https://groceries.asda.com/api/items/search', params=parameters)

# if the API call returns a successful response
if r.status_code==200:
    result = r.json()
    
    df = pd.DataFrame(result["items"])
    df.head()
# Out:
#          shelfId shelfName  ... salePrice positionChngByMargin
# 0  1215286383583   Corners  ...                              0
# 1  1215286383583   Corners  ...                              0
# 2  1215286383583   Corners  ...                              0
# 3  1215286383583   Corners  ...                              0
# 4  1215286383583   Corners  ...                              0
#
# [5 rows x 45 columns]

# %%
# Exercise 3.2. Parse JSON object (a dictionary)

# convert the first 2 items to string
s = json.dumps(result["items"][0:2], indent=4)
print(s)

# load back from a string
items = json.loads(s)
items

# save to file
json.dump(result["items"], open("items.json","w"))

# load back from file
items = json.load(open("items.json","r"))
print("test loaded data\n")
len(items)
items[0]
# Out:
# [
#     {
#         "shelfId": "1215286383583",
#         "shelfName": "Corners",
#         "deptId": "1215341888021",
#         "deptName": "Yogurts & Desserts",
#         "isBundle": "false",
#         "meatStickerDetails": "10::for::\u00a33.5::true",
#         "extraLargeImageURL": "",
#         "bundledItemCount": "0",
#         "scene7Host": "https://ui.assets-asda.com:443/dm/",
#         "cin": "6362225",
#         "promoDetailFull": "10 for \u00a33.5",
#         "availability": "A",
#         "totalReviewCount": "8",
#         "asdaSuggest": "",
#         "itemName": "Vanilla Yogurt with Chocolate\u00a0Balls",
#         "price": "\u00a30.55",
#         "imageURL": "",
#         "aisleName": "Yogurts & Fromage Frais",
#         "id": "1000120228362",
#         "promoId": "ls91195",
#         "isFavourite": "false",
#         "hasAlternates": "false",
#         "wasPrice": "",
#         "brandName": "Muller Corner",
#         "promoType": "No Promo",
#         "weight": "130g",
#         "promoOfferTypeCode": "15",
#         "promoQty": "10",
#         "promoValue": "\u00a33.50",
#         "productAttribute": "",
#         "scene7AssetId": "4025500245221",
#         "promoDetail": "10 for \u00a33.5",
#         "bundleDiscount": "0.00",
#         "avgStarRating": "4.625",
#         "name": "Muller Corner Vanilla Yogurt with Chocolate\u00a0Balls",
#         "avgWeight": "",
#         "iconDetails": {
#             "promotionalIcons": [
#                 "59600049"
#             ],
#             "informationalIcons": []
#         },
#         "maxQty": "10.0",
#         "pricePerWt": "Each",
#         "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000120228362",
#         "pricePerUOM": "",
#         "searchTuningScore": "1.869282E7",
#         "onSale": false,
#         "salePrice": "",
#         "positionChngByMargin": 0
#     },
#     {
#         "shelfId": "1215286383583",
#         "shelfName": "Corners",
#         "deptId": "1215341888021",
#         "deptName": "Yogurts & Desserts",
#         "isBundle": "false",
#         "meatStickerDetails": "10::for::\u00a33.5::true",
#         "extraLargeImageURL": "",
#         "bundledItemCount": "0",
#         "scene7Host": "https://ui.assets-asda.com:443/dm/",
#         "cin": "6362239",
#         "promoDetailFull": "10 for \u00a33.5",
#         "availability": "A",
#         "totalReviewCount": "3",
#         "asdaSuggest": "",
#         "itemName": "Strawberry Yogurt",
#         "price": "\u00a30.55",
#         "imageURL": "",
#         "aisleName": "Yogurts & Fromage Frais",
#         "id": "1000120228322",
#         "promoId": "ls91195",
#         "isFavourite": "false",
#         "hasAlternates": "false",
#         "wasPrice": "",
#         "brandName": "Muller Corner",
#         "promoType": "No Promo",
#         "weight": "143g",
#         "promoOfferTypeCode": "15",
#         "promoQty": "10",
#         "promoValue": "\u00a33.50",
#         "productAttribute": "",
#         "scene7AssetId": "4025500245092",
#         "promoDetail": "10 for \u00a33.5",
#         "bundleDiscount": "0.00",
#         "avgStarRating": "3.6667",
#         "name": "Muller Corner Strawberry Yogurt",
#         "avgWeight": "",
#         "iconDetails": {
#             "promotionalIcons": [
#                 "59600049"
#             ],
#             "informationalIcons": []
#         },
#         "maxQty": "10.0",
#         "pricePerWt": "Each",
#         "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000120228322",
#         "pricePerUOM": "",
#         "searchTuningScore": "1.3473809E7",
#         "onSale": false,
#         "salePrice": "",
#         "positionChngByMargin": 0
#     }
# ]
# [{'aisleName': 'Yogurts & Fromage Frais',
#   'asdaSuggest': '',
#   'availability': 'A',
#   'avgStarRating': '4.625',
#   'avgWeight': '',
#   'brandName': 'Muller Corner',
#   'bundleDiscount': '0.00',
#   'bundledItemCount': '0',
#   'cin': '6362225',
#   'deptId': '1215341888021',
#   'deptName': 'Yogurts & Desserts',
#   'extraLargeImageURL': '',
#   'hasAlternates': 'false',
#   'iconDetails': {'informationalIcons': [], 'promotionalIcons': ['59600049']},
#   'id': '1000120228362',
#   'imageURL': '',
#   'isBundle': 'false',
#   'isFavourite': 'false',
#   'itemName': 'Vanilla Yogurt with Chocolate\xa0Balls',
#   'maxQty': '10.0',
#   'meatStickerDetails': '10::for::£3.5::true',
#   'name': 'Muller Corner Vanilla Yogurt with Chocolate\xa0Balls',
#   'onSale': False,
#   'positionChngByMargin': 0,
#   'price': '£0.55',
#   'pricePerUOM': '',
#   'pricePerWt': 'Each',
#   'productAttribute': '',
#   'productURL': 'https://groceries.asda.com:443/api/items/view?itemid=1000120228362',
#   'promoDetail': '10 for £3.5',
#   'promoDetailFull': '10 for £3.5',
#   'promoId': 'ls91195',
#   'promoOfferTypeCode': '15',
#   'promoQty': '10',
#   'promoType': 'No Promo',
#   'promoValue': '£3.50',
#   'salePrice': '',
#   'scene7AssetId': '4025500245221',
#   'scene7Host': 'https://ui.assets-asda.com:443/dm/',
#   'searchTuningScore': '1.869282E7',
#   'shelfId': '1215286383583',
#   'shelfName': 'Corners',
#   'totalReviewCount': '8',
#   'wasPrice': '',
#   'weight': '130g'},
#  {'aisleName': 'Yogurts & Fromage Frais',
#   'asdaSuggest': '',
#   'availability': 'A',
#   'avgStarRating': '3.6667',
#   'avgWeight': '',
#   'brandName': 'Muller Corner',
#   'bundleDiscount': '0.00',
#   'bundledItemCount': '0',
#   'cin': '6362239',
#   'deptId': '1215341888021',
#   'deptName': 'Yogurts & Desserts',
#   'extraLargeImageURL': '',
#   'hasAlternates': 'false',
#   'iconDetails': {'informationalIcons': [], 'promotionalIcons': ['59600049']},
#   'id': '1000120228322',
#   'imageURL': '',
#   'isBundle': 'false',
#   'isFavourite': 'false',
#   'itemName': 'Strawberry Yogurt',
#   'maxQty': '10.0',
#   'meatStickerDetails': '10::for::£3.5::true',
#   'name': 'Muller Corner Strawberry Yogurt',
#   'onSale': False,
#   'positionChngByMargin': 0,
#   'price': '£0.55',
#   'pricePerUOM': '',
#   'pricePerWt': 'Each',
#   'productAttribute': '',
#   'productURL': 'https://groceries.asda.com:443/api/items/view?itemid=1000120228322',
#   'promoDetail': '10 for £3.5',
#   'promoDetailFull': '10 for £3.5',
#   'promoId': 'ls91195',
#   'promoOfferTypeCode': '15',
#   'promoQty': '10',
#   'promoType': 'No Promo',
#   'promoValue': '£3.50',
#   'salePrice': '',
#   'scene7AssetId': '4025500245092',
#   'scene7Host': 'https://ui.assets-asda.com:443/dm/',
#   'searchTuningScore': '1.3473809E7',
#   'shelfId': '1215286383583',
#   'shelfName': 'Corners',
#   'totalReviewCount': '3',
#   'wasPrice': '',
#   'weight': '143g'}]
# test loaded data
# 60
# {'aisleName': 'Yogurts & Fromage Frais',
#  'asdaSuggest': '',
#  'availability': 'A',
#  'avgStarRating': '4.625',
#  'avgWeight': '',
#  'brandName': 'Muller Corner',
#  'bundleDiscount': '0.00',
#  'bundledItemCount': '0',
#  'cin': '6362225',
#  'deptId': '1215341888021',
#  'deptName': 'Yogurts & Desserts',
#  'extraLargeImageURL': '',
#  'hasAlternates': 'false',
#  'iconDetails': {'informationalIcons': [], 'promotionalIcons': ['59600049']},
#  'id': '1000120228362',
#  'imageURL': '',
#  'isBundle': 'false',
#  'isFavourite': 'false',
#  'itemName': 'Vanilla Yogurt with Chocolate\xa0Balls',
#  'maxQty': '10.0',
#  'meatStickerDetails': '10::for::£3.5::true',
#  'name': 'Muller Corner Vanilla Yogurt with Chocolate\xa0Balls',
#  'onSale': False,
#  'positionChngByMargin': 0,
#  'price': '£0.55',
#  'pricePerUOM': '',
#  'pricePerWt': 'Each',
#  'productAttribute': '',
#  'productURL': 'https://groceries.asda.com:443/api/items/view?itemid=1000120228362',
#  'promoDetail': '10 for £3.5',
#  'promoDetailFull': '10 for £3.5',
#  'promoId': 'ls91195',
#  'promoOfferTypeCode': '15',
#  'promoQty': '10',
#  'promoType': 'No Promo',
#  'promoValue': '£3.50',
#  'salePrice': '',
#  'scene7AssetId': '4025500245221',
#  'scene7Host': 'https://ui.assets-asda.com:443/dm/',
#  'searchTuningScore': '1.869282E7',
#  'shelfId': '1215286383583',
#  'shelfName': 'Corners',
#  'totalReviewCount': '8',
#  'wasPrice': '',
#  'weight': '130g'}

# %% [markdown]
# ## 4. Get Tweets
#
# Reference:
# - https://github.com/scalto/snscrape-by-location/blob/main/snscrape_by_location_tutorial.ipynb
# - https://medium.com/swlh/how-to-scrape-tweets-by-location-in-python-using-snscrape-8c870fa6ec25
#
# Note: User object is not exposed by TwitterSearchScraper any more.

# %%
pip install snscrape
# Out:
# Collecting snscrape
#   Downloading snscrape-0.3.4-py3-none-any.whl (35 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from snscrape) (4.2.6)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.7/dist-packages (from snscrape) (2.23.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from snscrape) (4.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->snscrape) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->snscrape) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->snscrape) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->snscrape) (2.10)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->snscrape) (1.7.1)
# Installing collected packages: snscrape
# Successfully installed snscrape-0.3.4

# %%
import pandas as pd
import snscrape.modules.twitter as sntwitter
import itertools

# %%
#  search by keywords + time
# TwitterSearchScraper returns an interator, islice loops through the iterator

df = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    '"blockchain + since:2020-10-31 until:2020-11-03"').get_items(), 500))

print(len(df))
df.head()
# Out:
# 500
#                                                  url  ...            tcooutlinksss
# 0  https://twitter.com/zawphyowai199/status/13234...  ...  https://t.co/O83hXYOniH
# 1  https://twitter.com/CryptoWatchBot/status/1323...  ...
# 2  https://twitter.com/Rayinhosen/status/13234145...  ...  https://t.co/dcfBIyNYi4
# 3  https://twitter.com/coinmarketnet/status/13234...  ...  https://t.co/Ff0IdY5i1G
# 4  https://twitter.com/Link_Errors/status/1323414...  ...  https://t.co/6HpZOBOZzI
#
# [5 rows x 9 columns]

# %%
# search by user

df = pd.DataFrame(itertools.islice(sntwitter.TwitterUserScraper(
    '"zawphyowai199"').get_items(), 500))

print(len(df))
df.tail()
# Out:
# 500
#                                                    url  ...            tcooutlinksss
# 495  https://twitter.com/zawphyowai199/status/13669...  ...
# 496  https://twitter.com/zawphyowai199/status/13669...  ...  https://t.co/idnoWjNaUL
# 497  https://twitter.com/zawphyowai199/status/13669...  ...
# 498  https://twitter.com/zawphyowai199/status/13669...  ...
# 499  https://twitter.com/zawphyowai199/status/13667...  ...
#
# [5 rows x 9 columns]

# %% [markdown]
# ## 5. Tweepy
# - Tweepy is a python library to access Twitter API.
# - `pip install tweepy`
# - The Tweepy documentation has detailed explanations: https://docs.tweepy.org/en/stable/
# - You need to apply for a developer account from here: https://developer.twitter.com/en/apply-for-access

# %%
import tweepy
import csv
import datetime

# https://docs.tweepy.org/en/stable/auth_tutorial.html

# enter your account information
CONSUMER_KEY=''
CONSUMER_SECRET=''
ACCESS_KEY=''
ACCESS_SECRET=''

auth=tweepy.OAuthHandler(CONSUMER_KEY,CONSUMER_SECRET)
auth.set_access_token(ACCESS_KEY,ACCESS_SECRET)
api=tweepy.API(auth)

# %%
# Take a look at the public tweets from your account's home timeline 

public_tweets = api.home_timeline()
for tweet in public_tweets[:2]:
    print(tweet.text)
# Out:
# ---------------------------------------------------------------------------
# TweepError                                Traceback (most recent call last)
# <ipython-input-14-daf1be6d63c5> in <module>()
#       1 # Take a look at the public tweets from your account's home timeline
#       2
# ----> 3 public_tweets = api.home_timeline()
#       4 for tweet in public_tweets[:2]:
#       5     print(tweet.text)
#
# /usr/local/lib/python3.7/dist-packages/tweepy/binder.py in _call(*args, **kwargs)
#     251                 return method
#     252             else:
# --> 253                 return method.execute()
#     254         finally:
#     255             method.session.close()
#
# /usr/local/lib/python3.7/dist-packages/tweepy/binder.py in execute(self)
#     232                     raise RateLimitError(error_msg, resp)
#     233                 else:
# --> 234                     raise TweepError(error_msg, resp, api_code=api_error_code)
#     235
#     236             # Parse the response payload
#
# TweepError: [{'code': 215, 'message': 'Bad Authentication data.'}]

# %%
# is this useful information?
# Let's take a close look at ONE tweet json

public_tweets[0]
# there's no way to figure this out

# %%
# make it look better
# convert to string
json_str = json.dumps(public_tweets[0]._json)

# deserialise string into python object
parsed = json.loads(json_str)

print(json.dumps(parsed, indent=4, sort_keys=True))
# Now we can have a better idea of the clustered relations of the json object

# %% [markdown]
# ### 5.1. Get tweets from users' timeline
# - Make a Timeline call to retrieve the most recent 3200 tweets by a user (a rule set by Twitter).
#     - Note: the time range you get depends on how often the user posts tweets.
# - Parameters for the timeline call
#     - `count`: the number of results to try and retrieve per page. Maximum is 200.
#     - Make multiple calls to retrieve the 3200 tweets.
#     - `tweet_mode`:swaps the text index for full_text, and prevents a primary tweet longer than 140 characters from being truncated.
# - Variables of tweet objects
#     - https://docs.tweepy.org/en/stable/api.html#tweepy-api-twitter-api-wrapper

# %%
# Get the first five tweets of a user.
timeline = api.user_timeline("KelloggCompany",count=5,tweet_mode="extended")

for status in timeline:
    print (status.id)
    print (status.full_text)

# %%
# Step 1: get a list of tweets 
# Step 2: extract the varaibles you want

def get_all_tweets(user_name):
    auth=tweepy.OAuthHandler(CONSUMER_KEY,CONSUMER_SECRET)
    auth.set_access_token(ACCESS_KEY,ACCESS_SECRET)
    api=tweepy.API(auth)
    
    # initialize the first call
    alltweets=[]
    new_tweets=api.user_timeline(user_name, count=200)
    alltweets.extend(new_tweets)
    oldest=alltweets[-1].id-1  #next time start from the oldest one minus one 
    
    # continue to get tweets
    while len(new_tweets)>0:  
        print ("getting tweets before", oldest)
        new_tweets = api.user_timeline(user_name,count=200, max_id=oldest)
        alltweets.extend(new_tweets)
        oldest=alltweets[-1].id-1
        print("...{} tweets downloaded so far".format(len(alltweets)))
    
    # extract the variables you want
    outtweets = [[tweet.id_str, tweet.user.name, tweet.created_at, tweet.user.followers_count,
                  tweet.text.encode("utf-8")] for tweet in alltweets]
            
    # write out your variables
    with open('%s_tweet.csv' % user_name,'w') as outputfile: 
        writer=csv.writer(outputfile)
        writer.writerow(["id","user_name","created_at","followers","text"])
        writer.writerows(outtweets)
    pass

# use your function
if __name__ == '__main__':
    #pass in the username of the account you want to download
    get_all_tweets("KelloggCompany")

# %%
# Take a look at the table you got
df= pd.read_csv('KelloggCompany_tweet.csv', header=0)
df.head()

# how many tweets we get?
len(df)

# The first tweet is a retweet. Take a look at the text.
df.text[0]

# Let's compare it with the actual tweet. 
# You can find each tweet by its ID. 
# https://twitter.com/KelloggCompany/status/1438671732513116163

# %% [markdown]
# ### 5.2. Deal with truncated text
# - For text mining on Twitter, it is important to get the full text.
#     - Full text would be essential for topic modeling and sentiment analysis.
#     - Full text is also important for extracting mention networks (note the previous example).
# - Use the `tweet_mode="extended"` when calling a user's timeline.
#     - When using extended mode, the `text` attribute of Status objects returned is replaced by a `full_text` attribute, which contains the entire untruncated text of the Tweet.
# - Full text for tweets that are retweets.
#     - If the tweet is a retweet, the full_text is still truncated.
#     - We need to access the full text through `retweeted_status` attribute, which is a status object itself.
# - For reference: https://docs.tweepy.org/en/stable/extended_tweets.html

# %%
# Let's deal with retweets

def get_all_tweets(user_name):
    auth=tweepy.OAuthHandler(CONSUMER_KEY,CONSUMER_SECRET)
    auth.set_access_token(ACCESS_KEY,ACCESS_SECRET)
    api=tweepy.API(auth,wait_on_rate_limit=True)

    alltweets=[]
    new_tweets=api.user_timeline(user_name, count=200,tweet_mode="extended")
    alltweets.extend(new_tweets)
    oldest=alltweets[-1].id-1  
    
    # set date condition
    startDate=datetime.datetime(2021, 1, 1, 0, 0, 0)
    while new_tweets[-1].created_at > startDate:
        print ("getting tweets before", oldest)
        new_tweets = api.user_timeline(user_name,count=200, max_id=oldest)
        alltweets.extend(new_tweets)
        oldest=alltweets[-1].id-1
        print("...{} tweets downloaded so far".format(len(alltweets)))
        
    # check if it's a retweet
    # When using extended mode with a Retweet, the full_text attribute of the Status object may be truncated    
    # However, since the retweeted_status attribute (of a Status object that is a Retweet) is itself a Status object
    # the full_text attribute of the Retweeted Status object can be used instead.
    
    outtweets_all=[]
    for tweet in alltweets:
        status = api.get_status(tweet.id, tweet_mode="extended")
        
        if hasattr(status, "retweeted_status"):  # is a retweet
            full_text=status.retweeted_status.full_text.encode("utf-8")
            
            outtweets=[
            # tweet content
            tweet.id_str, tweet.created_at,full_text,
            # user features
            tweet.user.name, tweet.user.screen_name, tweet.user.followers_count, 
            # retweet features
            tweet.retweeted_status.user.name,tweet.retweeted_status.user.screen_name,tweet.retweeted_status.user.description]
            outtweets_all.append(outtweets)
  
        else: # not a retweet
            full_text=status.full_text.encode("utf-8")
                    
            outtweets=[
            # tweet content
            tweet.id_str, tweet.created_at,full_text,
            # user features
            tweet.user.name, tweet.user.screen_name, tweet.user.followers_count, 
            # retweet features
            "no value","no value","no value"]
            outtweets_all.append(outtweets)

    with open('%s_full_tweet.csv' % user_name,'w') as outputfile: 
        writer=csv.writer(outputfile)
        writer.writerow(["id","created_at","full_text",
                        "user.name","user.screen_name","user.followers_count",
                        "retweeted_status.user.name","retweeted_status.user.screen_name","retweeted_status.user.description"])
        writer.writerows(outtweets_all)

        
if __name__ == '__main__':
    #pass in the username of the account you want to download
    get_all_tweets("KelloggCompany")

# %%
df= pd.read_csv('KelloggCompany_full_tweet.csv', header=0)
df.head()
len(df)
# plese compare this full text with the above truncated text, what differences can you find?
df.full_text[0]

# %% [markdown]
# ### 5.3. Build Twitter networks
# - **Follower-followee network**
#     - If you have a list of user accounts, you may retrive the pairwise boolean values of following relations.
#     - Parameters
#         * `source_id` – The user_id of the subject user.
#         * `source_screen_name` – The screen_name of the subject user.
#         * `target_id` – The user_id of the target user.
#         * `target_screen_name` – The screen_name of the target user.
# - **Retweet network**
#     - Retweeted accounts can be extracted while scraping the API.
#     - Or retweeted accounts can be extracted from the text.
# - **Mention network**
#     - Can be extracted from the full text.

# %%
# How to scrape the follower-followee network?
# we can directly retrieve a bollean value 

dog="Microsoft"
cat="Oracle"

is_following = api.show_friendship(source_screen_name=dog,target_screen_name=cat)
print(is_following[1].following)

# Question: how to get the adjacency matrix of a follower-followee network?

# %% [markdown]
# ##### Twitter data resources
# https://github.com/echen102/us-pres-elections-2020 <br>
# https://github.com/echen102/COVID-19-TweetIDs
